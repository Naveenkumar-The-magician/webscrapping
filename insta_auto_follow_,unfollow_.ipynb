# %% [markdown]
# <a href="https://colab.research.google.com/github/Naveenkumar-The-magician/webscrapping/blob/main/insta_auto_follow_%2Cunfollow_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from selenium import webdriver as web
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import random
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import instaloader

L = instaloader.Instaloader()


bot_username = "naveenkumar_intern"
bot_password = "password"

profiles = ["naveenkumar_the_magician"]
amount = 30

# 'usernames' or 'links'
result = "usernames"

us = ""


class Instagram:
    def __init__(self, username, password):
        self.username = username
        self.password = password
        options = Options()
        options.add_experimental_option("excludeSwitches", ["enable-logging"])
        self.browser = web.Chrome("chromedriver", options=options)
        # self.browser.set_window_size(400, 900)

    def close_browser(self):
        self.browser.close()
        self.browser.quit()

    def login(self):
        browser = self.browser
        try:
            browser.get("https://www.instagram.com")
            time.sleep(random.randrange(3, 5))
            # Enter username:
            username_input = browser.find_element(By.NAME, "username")
            username_input.clear()
            username_input.send_keys(self.username)
            time.sleep(random.randrange(2, 4))
            # Enter password:
            password_input = browser.find_element(By.NAME, "password")
            password_input.clear()
            password_input.send_keys(self.password)
            time.sleep(random.randrange(1, 2))
            password_input.send_keys(Keys.ENTER)
            time.sleep(random.randrange(3, 5))
            print(f"[{self.username}] Successfully logged on!")
        except Exception as ex:
            print(f"[{self.username}] Authorization fail")
            self.close_browser()
        time.sleep(random.randrange(5, 7))

    def follow(self):
        user = ["naveenkumar_the_magician", "actormaddy", "actorsuriya", "actorvijay"]
        # user = user + rs
        browser = self.browser
        for i in range(len(user)):
            print(user[i])
            browser.get("https://www.instagram.com/" + user[i] + "/")
            time.sleep(random.randrange(5, 7))
            # follow = browser.find_element(
            #     By.TAG_NAME,
            #     value="button",
            # )

            # /html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/div[2]/section/main/div/header/section/div[1]/div[2]/div/div[1]/butto
            follow = browser.find_element(
                By.XPATH,
                value="//button[@class='_acan _acap _acas _aj1-']",
            )
            follow.click()

    def unfollow(self):
        user = ["naveenkumar_the_magician", "actormaddy", "actorsuriya", "actorvijay"]
        # user = user + rs
        browser = self.browser
        for i in range(len(user)):
            print(user[i])
            browser.get("https://www.instagram.com/" + user[i] + "/")
            time.sleep(random.randrange(5, 7))
            # follow = browser.find_element(
            #     By.TAG_NAME,
            #     value="button",
            # )
            follow = browser.find_element(
                By.XPATH,
                value="//button[@class='_acan _acap _acas _aj1-']",
            )
            follow.click()

    def followers(self):
        # amount = 5
        browser = self.browser
        user = ["sanmugavadivel_23"]
        # browser.get("https://www.instagram.com/helpamarketer/")
        for i in range(len(user)):
            browser.get("https://www.instagram.com/" + user[i] + "/followers/")
            time.sleep(random.randrange(3, 5))
            # followers_button = browser.find_element(
            #     By.XPATH,
            #     value="/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/div[2]/section/main/div/header/section/ul/li[3]/span/span",
            # )
            # count = followers_button.get_attribute("title")
            # if "," in count:
            #     count = int("".join(count.split(",")))
            # else:
            #     count = int(count)
            # if amount > count:
            #     print(
            #         f"You set amount = {amount} but there are {count} followers, then amount = {count}"
            #     )
            #     amount = count
            # followers_button.click()
            time.sleep(random.randrange(5, 7))

            # Get the followers box element
            followers_box = browser.find_element(
                By.XPATH, value='//div[@class="_aano"]'
            )

            # Scroll down the box to load all followers
            while True:
                # Get the current number of followers
                time.sleep(6)
                time.sleep(random.randrange(2, 4))
                num_followers = len(
                    browser.find_elements(
                        By.XPATH,
                        value='//div[@class="x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1pi30zi x1swvt13 xwib8y2 x1y1aw1k x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1"]',
                    )
                )

                # Scroll down the box
                browser.execute_script(
                    "arguments[0].scrollTop = arguments[0].scrollHeight", followers_box
                )

                # browser.execute_script(
                #     "window.scrollTo(0, document.body.scrollHeight);"
                # )

                # Wait for the box to load more followers
                time.sleep(6)

                # Check if the number of followers has changed
                new_num_followers = len(
                    browser.find_elements(
                        By.XPATH,
                        value='//div[@class="x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1pi30zi x1swvt13 xwib8y2 x1y1aw1k x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1"]',
                    )
                )
                if new_num_followers == num_followers:
                    break

            # Extract the usernames of each follower
            followers = [
                follower.text
                for follower in browser.find_elements(
                    By.XPATH,
                    value='//div[@class="x9f619 xjbqb8w x1rg5ohu x168nmei x13lgxp2 x5pf9jr xo71vjh x1n2onr6 x1plvlek xryxfnj x1c4vz4f x2lah0s x1q0g3np xqjyukv x6s0dn4 x1oa3qoh x1nhvcw1"]',
                )
            ]

            # username = [
            #     follower.text
            #     for follower in browser.find_elements(
            #         By.CSS_SELECTOR,
            #         value="#mount_0_0_KB > div > div > div:nth-child(3) > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div.x1uvtmcs.x4k7w5x.x1h91t0o.x1beo9mf.xaigb6o.x12ejxvf.x3igimt.xarpa2k.xedcshv.x1lytzrv.x1t2pt76.x7ja8zs.x1n2onr6.x1qrby5j.x1jfb8zj > div > div > div > div > div.x7r02ix.xf1ldfh.x131esax.xdajt7p.xxfnqb6.xb88tzc.xw2csxc.x1odjw0f.x5fp0pe > div > div > div._aano > div > div > div:nth-child(1) > div > div > div > div.x9f619.x1n2onr6.x1ja2u2z.x78zum5.x1iyjqo2.xs83m0k.xeuugli.x1qughib.x6s0dn4.x1a02dak.x1q0g3np.xdl72j9 > div > div > span.x1lliihq.x1plvlek.xryxfnj.x1n2onr6.x193iq5w.xeuugli.x1fj9vlw.x13faqbe.x1vvkbs.x1s928wv.xhkezso.x1gmr53x.x1cpjm7i.x1fgarty.x1943h6x.x1i0vuye.xvs91rp.xo1l8bm.x1roi4f4.x10wh9bi.x1wdrske.x8viiok.x18hxmgj > span",
            #     )
            # ]

            # print(username)
            print(followers)
            print(len(followers))

        return followers, len(followers)

        # self.follow(followers)

    def following(self):
        browser = self.browser

        user = ["sanmugavadivel_23"]
        # browser.get("https://www.instagram.com/helpamarketer/")
        for i in range(len(user)):
            browser.get("https://www.instagram.com/" + user[i] + "/following/")
            # following_button = browser.find_element(
            #     By.XPATH,
            #     value="/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/div[2]/section/main/div/header/section/ul/li[2]/a/span",
            # )
            # count = following_button.get_attribute("title")
            time.sleep(random.randrange(5, 7))

            # Get the followers box element
            following_box = browser.find_element(
                By.XPATH, value='//div[@class="_aano"]'
            )

            # Scroll down the box to load all followers
            while True:
                # Get the current number of followers
                time.sleep(random.randrange(2, 4))
                time.sleep(6)
                num_following = len(
                    browser.find_elements(
                        By.XPATH,
                        value='//div[@class="x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1pi30zi x1swvt13 xwib8y2 x1y1aw1k x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1"]',
                    )
                )

                # Scroll down the box
                browser.execute_script(
                    "arguments[0].scrollTop = arguments[0].scrollHeight", following_box
                )

                # # Wait for the box to load more followers
                # time.sleep(random.randrange(0, 1))

                # browser.execute_script(
                #     "window.scrollTo(0, document.body.scrollHeight);"
                # )

                # Wait for the box to load more followers
                time.sleep(6)

                # Check if the number of followers has changed
                new_num_following = len(
                    browser.find_elements(
                        By.XPATH,
                        value='//div[@class="x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1pi30zi x1swvt13 xwib8y2 x1y1aw1k x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1"]',
                    )
                )
                if new_num_following == num_following:
                    break

            # Extract the usernames of each follower
            following = [
                followee.text
                for followee in browser.find_elements(
                    By.XPATH,
                    value='//div[@class="x9f619 xjbqb8w x1rg5ohu x168nmei x13lgxp2 x5pf9jr xo71vjh x1n2onr6 x1plvlek xryxfnj x1c4vz4f x2lah0s x1q0g3np xqjyukv x6s0dn4 x1oa3qoh x1nhvcw1"]',
                )
            ]

            print(following)
            print(len(following))

        return following, len(following)

    def details(self, users, length):
        login = open(r"C:\Users\lsiva\OneDrive\Desktop\insta scrap\login.txt")
        line = login.readlines()
        username = line[0]
        password = line[1]
        for i in range(length):
            L.login(username, password)

            profile = instaloader.Profile.from_username(L.context, users[i])

            print("Username: ", profile.username)
            print("Full Name: ", profile.full_name)
            print("profile_pic_url:", profile.profile_pic_url)
            print("Followers: ", profile.followers)
            print("Following: ", profile.followees)
            print("Bio: ", profile.biography)
            print("is_business_account:", profile.is_business_account)
            print("business_category_name:", profile.business_category_name)
            print("is_private:", profile.is_private)
            print("is_verified: ", profile.is_verified)
            print("external_url", profile.external_url)
            print("\n\n")

    def popup(self):
        # first pop-up
        self.browser.find_element(
            By.XPATH,
            "/html/body/div[2]/div/div/div[2]/div/div/div/div[1]/div[1]/div[2]/section/main/div/div/div/div/div",
        ).click()
        time.sleep(2)

        # 2nd pop-up
        self.browser.find_element(
            By.XPATH,
            "/html/body/div[2]/div/div/div[3]/div/div/div[1]/div/div[2]/div/div/div/div/div[2]/div/div/div[3]/button[2]",
        ).click()


bot = Instagram(bot_username, bot_password)
bot.login()
# bot.popup()
followers, len_followers = bot.followers()
# bot.follow()
following, len_following = bot.following()


print("follower of sanmuga")
bot.details(followers, len_followers)

print("*********")
print("following of sanmuga")
bot.details(following, len_following)

bot.unfollow()
bot.follow()
